# %%
import numpy as np 

#4 users give rating out of 5 to 5 different food items from zomato 
arr=np.array([[2,3,4,5,1],
              [2,3,5,1,3],
              [2,4,3,5,2],
              [4,5,3,5,5]])
print("Rating Given by second user are :",arr[1])
print("Rating given by 3rd User are:",arr[2])


steps=np.array([7500,8200,9000,10000,5400,9500,4500,8400,9800,2000])
print("steps were greater than 8000 are:",np.where(steps>8000))
print("steps were greater than 8000 are:",steps[np.where(steps>8000)])


ipl=np.array([230,345,250,345,120,267,231,123])
print("Matches 2,5 and 7 scores :",ipl[[1,4,6]])


price=np.array([2300,4500,400,230,1230,3400])
print("Original price :",price)
new_price=price*0.90
print("Price after 10% discount :",new_price)

ratings=np.array([5,4,0,-2,3,1,0,-1,-4,5,2])
ratings[ratings<0]=0
print(ratings)
# Out:
# Rating Given by second user are : [2 3 5 1 3]
# Rating given by 3rd User are: [2 4 3 5 2]
# steps were greater than 8000 are: (array([1, 2, 3, 5, 7, 8]),)
# steps were greater than 8000 are: [ 8200  9000 10000  9500  8400  9800]
# Matches 2,5 and 7 scores : [345 120 231]
# Original price : [2300 4500  400  230 1230 3400]
# Price after 10% discount : [2070. 4050.  360.  207. 1107. 3060.]
# [5 4 0 0 3 1 0 0 0 5 2]
